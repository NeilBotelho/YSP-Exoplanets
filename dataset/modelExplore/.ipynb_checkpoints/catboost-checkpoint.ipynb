# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import balanced_accuracy_score
from catboost import CatBoostClassifier
import math as m
from imblearn.over_sampling import SMOTE
import random as r
import sys

r.seed(300)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
exoData=pd.read_csv('../simpleImputedMiceRf')
#These are the row_ids of exoplanets that are known to be habitable
habitableRows=[151, 152, 153, 1604, 2155, 2223, 2882, 3133, 3606, 3716, 3742,3743, 3744]

#Creates a Series that uses 1 or 0 to indicate whether a corresponding record in the exoData
habitable=exoData.row_id.isin(habitableRows).replace(True,1).rename('habitable')

#Store row ids series and remove for scaling all data to values between 0 and 1
row_id=exoData.row_id
data=exoData.drop('row_id',axis=1)
scaledData=pd.DataFrame(StandardScaler().fit_transform(data),columns=data.columns)

#join the scaled data columns, row_id and habitable column,into the variable preprocessed and shuffle
preprocessed=pd.concat([row_id,scaledData,habitable],axis=1)
preprocessed=shuffle(preprocessed,random_state=100).reset_index()
preprocessed=preprocessed.drop('index',axis=1)   
print('Done')
# Out:
# Done

# %%
#List of columns to be used for training
#it will be all columns in preprocessed except for "habitable" and "row_id"
trainCols=[x for x in preprocessed.columns if x not in ['habitable','row_id']]
validate=[]
Hcopy=habitableRows.copy()

#numHidden sets the number of habitable planets to use for validation of the model
numHidden=round(len(Hcopy)/2)

#Randomly select "numHidden" number of habitable exoplanets and
#add their row_id to validation set 
print("Hiding ",numHidden," habitable(",end="")
for i in range(numHidden): 
    randNum=r.randint(0,len(Hcopy)-1)
    validate.append(Hcopy[randNum])
    print(Hcopy[randNum],end=",")
    del Hcopy[randNum]
print("\b )")

#Add row_id of non-habitable planets to the validation set till its length becomes 100
while len(validate)<100:
    temp=r.randint(0,3500)
    if temp not in habitableRows:
        validate.append(temp)

#Take all columns of the planets whose row_id is in "validate" variable(in the validation set) and
#store it in "validate" variable
validate=preprocessed[preprocessed.row_id.isin(validate)]

#Store the planets that are not in the validation set in the training set
trainingSet=preprocessed[~preprocessed.row_id.isin(validate.row_id)]

#Store the training features in X and target feature(habitable or not) in y 
X=trainingSet[trainCols]
y=trainingSet.habitable

#the SMOTE library mutates existing data to creating more data
#Here we use SMOTE to increase the number of habitable planets in the training and validation data
smote = SMOTE(ratio='minority')
X_sm, y_sm = smote.fit_sample(X, y)
validateX,validateY=smote.fit_sample(validate[trainCols],validate.habitable)
# Out:
#  )

# %%
Bestscores=[-1,{}]
n_iterations=[10,100,500,1000,2000]
LR=[0.1,0.01,0.001,0.00001]
n_estimators=[10,50,100,200]
max_features=[1,0.5,0.1,0.01]
depth=[2,3,5,7]
num=0
loss_function=['Logloss','CrossEntropy','MultiClass', 'MultiClassOneVsAll' ]
for n in n_estimators:
    for d in depth:
        for lr in LR:
            for ls in loss_function:
                        test_model=CatBoostClassifier(iterations=n,learning_rate=lr,depth=d,loss_function=ls,logging_level='Silent',thread_count=-1)
                        test_model.fit(X_sm,y_sm)
                        y_preds=test_model.predict(validateX)
                        num+=1
                        print("Done with",test_model.get_params(),"\n",num)
                        currScore=balanced_accuracy_score(validateY,y_preds)
                        if(currScore>Bestscores[0]):
                            Bestscores[0]=currScore
                            Bestscores[1]=test_model.get_params()
Bestscores
# Out:
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.1, 'iterations': 10}
#  1
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.1, 'iterations': 10}
#  2
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.1, 'iterations': 10}
#  3
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.1, 'iterations': 10}
#  4
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.01, 'iterations': 10}
#  5
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.01, 'iterations': 10}
#  6
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.01, 'iterations': 10}
#  7
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.01, 'iterations': 10}
#  8
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.001, 'iterations': 10}
#  9
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.001, 'iterations': 10}
#  10
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.001, 'iterations': 10}
#  11
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.001, 'iterations': 10}
#  12
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 10}
#  13
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 10}
#  14
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 10}
#  15
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 10}
#  16
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.1, 'iterations': 10}
#  17
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.1, 'iterations': 10}
#  18
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.1, 'iterations': 10}
#  19
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.1, 'iterations': 10}
#  20
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.01, 'iterations': 10}
#  21
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.01, 'iterations': 10}
#  22
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.01, 'iterations': 10}
#  23
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.01, 'iterations': 10}
#  24
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.001, 'iterations': 10}
#  25
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.001, 'iterations': 10}
#  26
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.001, 'iterations': 10}
#  27
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.001, 'iterations': 10}
#  28
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 10}
#  29
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 10}
#  30
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 10}
#  31
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 10}
#  32
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.1, 'iterations': 10}
#  33
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.1, 'iterations': 10}
#  34
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.1, 'iterations': 10}
#  35
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.1, 'iterations': 10}
#  36
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.01, 'iterations': 10}
#  37
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.01, 'iterations': 10}
#  38
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.01, 'iterations': 10}
#  39
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.01, 'iterations': 10}
#  40
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.001, 'iterations': 10}
#  41
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.001, 'iterations': 10}
#  42
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.001, 'iterations': 10}
#  43
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.001, 'iterations': 10}
#  44
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 10}
#  45
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 10}
#  46
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 10}
#  47
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 10}
#  48
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.1, 'iterations': 10}
#  49
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.1, 'iterations': 10}
#  50
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.1, 'iterations': 10}
#  51
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.1, 'iterations': 10}
#  52
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.01, 'iterations': 10}
#  53
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.01, 'iterations': 10}
#  54
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.01, 'iterations': 10}
#  55
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.01, 'iterations': 10}
#  56
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.001, 'iterations': 10}
#  57
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.001, 'iterations': 10}
#  58
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.001, 'iterations': 10}
#  59
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.001, 'iterations': 10}
#  60
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 10}
#  61
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 10}
#  62
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 10}
#  63
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 10}
#  64
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.1, 'iterations': 50}
#  65
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.1, 'iterations': 50}
#  66
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.1, 'iterations': 50}
#  67
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.1, 'iterations': 50}
#  68
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.01, 'iterations': 50}
#  69
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.01, 'iterations': 50}
#  70
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.01, 'iterations': 50}
#  71
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.01, 'iterations': 50}
#  72
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.001, 'iterations': 50}
#  73
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.001, 'iterations': 50}
#  74
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.001, 'iterations': 50}
#  75
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.001, 'iterations': 50}
#  76
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 50}
#  77
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 50}
#  78
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 50}
#  79
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 50}
#  80
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.1, 'iterations': 50}
#  81
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.1, 'iterations': 50}
#  82
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.1, 'iterations': 50}
#  83
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.1, 'iterations': 50}
#  84
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.01, 'iterations': 50}
#  85
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.01, 'iterations': 50}
#  86
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.01, 'iterations': 50}
#  87
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.01, 'iterations': 50}
#  88
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.001, 'iterations': 50}
#  89
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.001, 'iterations': 50}
#  90
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.001, 'iterations': 50}
#  91
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.001, 'iterations': 50}
#  92
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 50}
#  93
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 50}
#  94
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 50}
#  95
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 50}
#  96
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.1, 'iterations': 50}
#  97
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.1, 'iterations': 50}
#  98
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.1, 'iterations': 50}
#  99
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.1, 'iterations': 50}
#  100
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.01, 'iterations': 50}
#  101
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.01, 'iterations': 50}
#  102
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.01, 'iterations': 50}
#  103
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.01, 'iterations': 50}
#  104
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.001, 'iterations': 50}
#  105
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.001, 'iterations': 50}
#  106
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.001, 'iterations': 50}
#  107
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.001, 'iterations': 50}
#  108
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 50}
#  109
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 50}
#  110
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 50}
#  111
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 50}
#  112
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.1, 'iterations': 50}
#  113
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.1, 'iterations': 50}
#  114
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.1, 'iterations': 50}
#  115
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.1, 'iterations': 50}
#  116
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.01, 'iterations': 50}
#  117
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.01, 'iterations': 50}
#  118
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.01, 'iterations': 50}
#  119
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.01, 'iterations': 50}
#  120
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.001, 'iterations': 50}
#  121
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.001, 'iterations': 50}
#  122
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.001, 'iterations': 50}
#  123
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.001, 'iterations': 50}
#  124
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 50}
#  125
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 50}
#  126
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 50}
#  127
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 50}
#  128
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.1, 'iterations': 100}
#  129
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.1, 'iterations': 100}
#  130
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.1, 'iterations': 100}
#  131
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.1, 'iterations': 100}
#  132
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.01, 'iterations': 100}
#  133
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.01, 'iterations': 100}
#  134
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.01, 'iterations': 100}
#  135
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.01, 'iterations': 100}
#  136
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.001, 'iterations': 100}
#  137
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.001, 'iterations': 100}
#  138
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.001, 'iterations': 100}
#  139
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.001, 'iterations': 100}
#  140
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 100}
#  141
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 100}
#  142
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 100}
#  143
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 100}
#  144
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.1, 'iterations': 100}
#  145
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.1, 'iterations': 100}
#  146
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.1, 'iterations': 100}
#  147
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.1, 'iterations': 100}
#  148
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.01, 'iterations': 100}
#  149
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.01, 'iterations': 100}
#  150
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.01, 'iterations': 100}
#  151
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.01, 'iterations': 100}
#  152
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.001, 'iterations': 100}
#  153
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.001, 'iterations': 100}
#  154
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.001, 'iterations': 100}
#  155
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.001, 'iterations': 100}
#  156
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 100}
#  157
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 100}
#  158
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 100}
#  159
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 100}
#  160
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.1, 'iterations': 100}
#  161
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.1, 'iterations': 100}
#  162
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.1, 'iterations': 100}
#  163
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.1, 'iterations': 100}
#  164
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.01, 'iterations': 100}
#  165
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.01, 'iterations': 100}
#  166
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.01, 'iterations': 100}
#  167
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.01, 'iterations': 100}
#  168
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.001, 'iterations': 100}
#  169
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.001, 'iterations': 100}
#  170
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.001, 'iterations': 100}
#  171
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.001, 'iterations': 100}
#  172
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 100}
#  173
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 100}
#  174
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 100}
#  175
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 100}
#  176
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.1, 'iterations': 100}
#  177
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.1, 'iterations': 100}
#  178
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.1, 'iterations': 100}
#  179
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.1, 'iterations': 100}
#  180
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.01, 'iterations': 100}
#  181
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.01, 'iterations': 100}
#  182
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.01, 'iterations': 100}
#  183
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.01, 'iterations': 100}
#  184
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.001, 'iterations': 100}
#  185
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.001, 'iterations': 100}
#  186
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.001, 'iterations': 100}
#  187
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.001, 'iterations': 100}
#  188
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 100}
#  189
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 100}
#  190
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 100}
#  191
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 100}
#  192
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.1, 'iterations': 200}
#  193
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.1, 'iterations': 200}
#  194
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.1, 'iterations': 200}
#  195
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.1, 'iterations': 200}
#  196
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.01, 'iterations': 200}
#  197
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.01, 'iterations': 200}
#  198
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.01, 'iterations': 200}
#  199
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.01, 'iterations': 200}
#  200
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 0.001, 'iterations': 200}
#  201
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 0.001, 'iterations': 200}
#  202
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 0.001, 'iterations': 200}
#  203
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 0.001, 'iterations': 200}
#  204
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 200}
#  205
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 200}
#  206
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 200}
#  207
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 2, 'learning_rate': 1e-05, 'iterations': 200}
#  208
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.1, 'iterations': 200}
#  209
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.1, 'iterations': 200}
#  210
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.1, 'iterations': 200}
#  211
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.1, 'iterations': 200}
#  212
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.01, 'iterations': 200}
#  213
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.01, 'iterations': 200}
#  214
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.01, 'iterations': 200}
#  215
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.01, 'iterations': 200}
#  216
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 0.001, 'iterations': 200}
#  217
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 0.001, 'iterations': 200}
#  218
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 0.001, 'iterations': 200}
#  219
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 0.001, 'iterations': 200}
#  220
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 200}
#  221
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 200}
#  222
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 200}
#  223
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 3, 'learning_rate': 1e-05, 'iterations': 200}
#  224
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.1, 'iterations': 200}
#  225
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.1, 'iterations': 200}
#  226
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.1, 'iterations': 200}
#  227
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.1, 'iterations': 200}
#  228
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.01, 'iterations': 200}
#  229
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.01, 'iterations': 200}
#  230
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.01, 'iterations': 200}
#  231
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.01, 'iterations': 200}
#  232
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 0.001, 'iterations': 200}
#  233
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 0.001, 'iterations': 200}
#  234
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 0.001, 'iterations': 200}
#  235
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 0.001, 'iterations': 200}
#  236
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 200}
#  237
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 200}
#  238
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 200}
#  239
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 5, 'learning_rate': 1e-05, 'iterations': 200}
#  240
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.1, 'iterations': 200}
#  241
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.1, 'iterations': 200}
#  242
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.1, 'iterations': 200}
#  243
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.1, 'iterations': 200}
#  244
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.01, 'iterations': 200}
#  245
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.01, 'iterations': 200}
#  246
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.01, 'iterations': 200}
#  247
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.01, 'iterations': 200}
#  248
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 0.001, 'iterations': 200}
#  249
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 0.001, 'iterations': 200}
#  250
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 0.001, 'iterations': 200}
#  251
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 0.001, 'iterations': 200}
#  252
# Done with {'logging_level': 'Silent', 'loss_function': 'Logloss', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 200}
#  253
# Done with {'logging_level': 'Silent', 'loss_function': 'CrossEntropy', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 200}
#  254
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClass', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 200}
#  255
# Done with {'logging_level': 'Silent', 'loss_function': 'MultiClassOneVsAll', 'depth': 7, 'learning_rate': 1e-05, 'iterations': 200}
#  256
# [0.8246753246753247,
#  {'depth': 3,
#   'iterations': 10,
#   'learning_rate': 0.1,
#   'logging_level': 'Silent',
#   'loss_function': 'MultiClass'}]

# %%
final=CatBoostClassifier(depth=3,iterations=10,learning_rate=0.1,logging_level='Silent',loss_function='MultiClass')
final.fit(X_sm,y_sm)
#Get Feature importance from best model
feats=final.get_feature_importance(type='PredictionValuesChange')
feats=list(X.columns)
for value in range(len(a)):
    print(feats[value],a[value])
# Out:
# pl_controvflag 0.0
# pl_pnum 0.0
# pl_orbper 3.1598259123680057
# pl_orbsmax 0.0
# pl_radj 0.0
# pl_ttvflag 0.0
# pl_kepflag 0.0
# pl_k2flag 0.0
# ra 1.2818512570677536
# dec 0.0
# st_dist 0.0
# st_optmag 1.3134362370487753
# gaia_gmag 1.1029854204385408
# st_teff 0.0
# st_mass 4.646859774253571
# st_rad 0.0
# pl_tranflag 0.0
# pl_rvflag 0.0
# pl_imgflag 0.0
# pl_astflag 0.0
# pl_omflag 0.0
# pl_cbflag 0.0
# pl_angsep 0.0
# pl_rade 0.0
# pl_rads 0.0
# pl_trandur 0.0
# pl_tranmid 0.0
# pl_ratror 0.0
# pl_mnum 0.0
# pl_st_npar 0.22932228758691564
# pl_st_nref 0.0
# st_rah 0.0
# st_glon 0.0
# st_glat 0.0
# st_elon 2.4495670104719447
# st_elat 0.0
# gaia_plx 0.0
# gaia_dist 2.726371700115607
# st_pmra 0.0
# st_pmdec 0.3936826722614326
# st_pm 0.0
# gaia_pmra 60.60460491047441
# gaia_pmdec 0.0
# gaia_pm 20.809147141735924
# st_logg 0.0
# st_metfe 0.0
# st_j 0.0
# st_h 0.0
# st_k 0.0
# st_wise1 0.0
# st_wise2 0.0
# st_wise3 0.0
# st_wise4 0.0
# st_jmh2 0.6134555463443907
# st_hmk2 0.0
# st_jmk2 0.6688901298327542
